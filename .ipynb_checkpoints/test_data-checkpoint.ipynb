# %%
import pandas as pd
from sklearn import preprocessing
import numpy as np
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('./data/dataset_wx_web.csv')
df
# Out:
#             date  oneDayBefore  twoDayBefore  threeDayBefore  oneMonthBefore  \
# 0     2015-01-01          2.36          2.33        2.350000        2.450000
# 1     2015-01-02          2.49          2.36        2.330000        2.420000
# 2     2015-01-03          2.52          2.49        2.360000        2.360000
# 3     2015-01-04          2.53          2.52        2.490000        2.290000
# 4     2015-01-05          2.25          2.53        2.520000        2.360000
# 5     2015-01-06          2.31          2.25        2.530000        2.410000
# 6     2015-01-07          2.28          2.31        2.250000        2.380000
# 7     2015-01-08          2.24          2.28        2.310000        2.450000
# 8     2015-01-09          2.28          2.24        2.280000        2.300000
# 9     2015-01-10          2.28          2.28        2.240000        2.240000
# 10    2015-01-11          2.33          2.28        2.280000        2.320000
# ...

# %%
df =df.drop_duplicates(subset='date', keep='first', inplace=False)
df.set_index('date')
sd.to_csv('./data/dataset_wx_web.csv')
# Out:
#             oneDayBefore  twoDayBefore  threeDayBefore  oneMonthBefore  \
# date
# 2015-01-01          2.36          2.33        2.350000        2.450000
# 2015-01-02          2.49          2.36        2.330000        2.420000
# 2015-01-03          2.52          2.49        2.360000        2.360000
# 2015-01-04          2.53          2.52        2.490000        2.290000
# 2015-01-05          2.25          2.53        2.520000        2.360000
# 2015-01-06          2.31          2.25        2.530000        2.410000
# 2015-01-07          2.28          2.31        2.250000        2.380000
# 2015-01-08          2.24          2.28        2.310000        2.450000
# 2015-01-09          2.28          2.24        2.280000        2.300000
# 2015-01-10          2.28          2.28        2.240000        2.240000
# 2015-01-11          2.33          2.28        2.280000        2.320000
# 2015-01-12          2.52          2.33        2.280000        2.420000
# ...

# %%
# 标准化
X_data = df.iloc[:, 0:-1]
Y_data = df['price'].values.reshape(-1, 1)
scaler_X = preprocessing.StandardScaler(copy=True, with_mean=True, with_std=True).fit(X_data)
scaler_Y = preprocessing.StandardScaler(copy=True, with_mean=True, with_std=True).fit(Y_data)

# %%
startDate = "2018-12-3"
endDate = "2018-12-31"
df = df.loc[startDate:endDate]
df
# Out:
#             oneDayBefore  twoDayBefore  threeDayBefore  oneMonthBefore  \
# date
# 2018-12-30          2.17          2.17        2.200000        2.110000
# 2018-12-31          2.27          2.17        2.265104        2.268867
#
#             oneYearBefore  dollorRate  price
# date
# 2018-12-30           1.99  686.320007   2.27
# 2018-12-31           2.06  686.320007   2.18

# %%
datelist = pd.date_range(startDate,endDate)
datelist = [x.strftime('%Y-%m-%d') for x in datelist]
datelist
# Out:
# ['2018-11-30',
#  '2018-12-01',
#  '2018-12-02',
#  '2018-12-03',
#  '2018-12-04',
#  '2018-12-05',
#  '2018-12-06',
#  '2018-12-07',
#  '2018-12-08',
#  '2018-12-09',
#  '2018-12-10',
#  '2018-12-11',
#  '2018-12-12',
#  '2018-12-13',
#  '2018-12-14',
#  '2018-12-15',
#  '2018-12-16',
#  '2018-12-17',
#  '2018-12-18',
#  '2018-12-19',
#  '2018-12-20',
#  '2018-12-21',
#  '2018-12-22',
#  '2018-12-23',
#  '2018-12-24',
#  '2018-12-25',
#  '2018-12-26',
#  '2018-12-27',
#  '2018-12-28',
#  '2018-12-29',
#  '2018-12-30',
#  '2018-12-31']

# %%
X = scaler_X.transform(df.iloc[:,0:-1])
X
# Out:
# array([[-3.90921118e-01, -5.24281955e-01, -6.18903371e-01,
#         -2.64339615e-01,  4.97960288e-01, -9.14847769e-02],
#        [-4.09987324e-01, -3.90825114e-01, -5.23717915e-01,
#         -5.49489353e-02,  4.12178421e-01, -9.14847769e-02],
#        [-4.67185942e-01, -4.09890377e-01, -3.90458276e-01,
#         -1.69162034e-01,  1.37676447e-01, -1.77108837e-01],
#        ...,
#        [-1.81192852e-01, -1.23911431e-01, -1.42976089e-01,
#         -2.64339615e-01, -7.37298597e-01,  1.17399293e+00],
#        [-1.81192852e-01, -1.81107221e-01, -1.23938998e-01,
#         -3.02410648e-01, -6.51516730e-01,  1.16409824e+00],
#        [ 9.46920822e-03, -1.81107221e-01,  0.00000000e+00,
#         -2.53604023e-15, -5.31422116e-01,  1.16409824e+00]])

# %%
Y = scaler_Y.transform(df['price'].values.reshape(-1, 1))
Y
# Out:
# array([[-0.40904066],
#        [-0.46623735],
#        [-0.5424996 ],
#        [-0.42810622],
#        [-0.44717179],
#        [-0.37090954],
#        [-0.42810622],
#        [-0.40904066],
#        [-0.63782742],
#        [-0.59969629],
#        [-0.73315523],
#        [-0.56156516],
#        [-0.63782742],
#        [-0.5424996 ],
#        [-0.63782742],
#        [-0.61876185],
#        [-0.65689298],
#        [-0.61876185],
#        [-0.61876185],
#        [-0.42810622],
#        [-0.46623735],
#        [-0.6950241 ],
#        [-0.59969629],
#        [-0.48530291],
#        [-0.33277841],
#        [-0.08492609],
#        [-0.08492609],
#        [-0.04679497],
#        [-0.37090954],
#        [-0.56156516],
#        [-0.48530291],
#        [-0.61876185],
#        [-0.63782742],
#        [-0.61876185],
#        [-0.3899751 ],
#        [-0.52343404],
#        [-0.44717179],
#        [-0.50436848],
#        [-0.42810622],
#        [-0.42810622],
#        [-0.33277841],
# ...

# %%
model = load_model('./best_model_tanh/model.hdf5')
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\ML\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\ML\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\ML\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
pred = scaler_Y.inverse_transform(model.predict(X))
pred
# Out:
# array([[2.0304248],
#        [2.0379777],
#        [2.0294826],
#        [1.9990906],
#        [2.026311 ],
#        [2.0276778],
#        [2.0598142],
#        [2.046449 ],
#        [2.052798 ],
#        [1.9682399],
#        [1.9620996],
#        [1.9082512],
#        [1.9564599],
#        [1.9387237],
#        [1.9717424],
#        [1.9459108],
#        [1.9540014],
#        [1.9376551],
#        [1.9496181],
#        [1.9511731],
#        [2.0237978],
#        [2.0290287],
#        [1.9545442],
#        [1.9624959],
#        [1.9983873],
#        [2.0721138],
#        [2.196053 ],
#        [2.230674 ],
#        [2.260201 ],
#        [2.138041 ],
#        [2.037647 ],
#        [2.0258968],
#        [1.977353 ],
#        [1.9656247],
#        [1.9614961],
#        [2.0447032],
#        [2.0167828],
#        [2.0465767],
#        [2.0262072],
#        [2.057954 ],
#        [2.0579324],
#        [2.0994232],
#        [2.2251499],
#        [2.1757877],
#        [2.2954412],
# ...

# %%
pred.flatten()
# Out:
# array([2.0304248, 2.0379777, 2.0294826, 1.9990906, 2.026311 , 2.0276778,
#        2.0598142, 2.046449 , 2.052798 , 1.9682399, 1.9620996, 1.9082512,
#        1.9564599, 1.9387237, 1.9717424, 1.9459108, 1.9540014, 1.9376551,
#        1.9496181, 1.9511731, 2.0237978, 2.0290287, 1.9545442, 1.9624959,
#        1.9983873, 2.0721138, 2.196053 , 2.230674 , 2.260201 , 2.138041 ,
#        2.037647 , 2.0258968, 1.977353 , 1.9656247, 1.9614961, 2.0447032,
#        2.0167828, 2.0465767, 2.0262072, 2.057954 , 2.0579324, 2.0994232,
#        2.2251499, 2.1757877, 2.2954412, 2.3613524, 2.4906294, 2.2061899,
#        2.1491847, 2.0909495, 2.0884209, 2.088952 , 2.0928075, 2.091267 ,
#        2.1248264, 2.1914833, 2.140079 , 2.1629982, 2.1982765, 2.1919332,
#        2.2005634, 2.202105 , 2.2151327, 2.2333555, 2.206774 , 2.226971 ,
#        2.2769144, 2.1661177, 2.1482856, 2.1509178, 2.130249 , 2.1364863,
#        2.1374314, 2.1452978, 2.1195898, 2.0761557, 2.0320563, 2.1255243,
# ...

# %%
startDate = "2018-01-01"
endDate = "2018-12-31"
datelist = pd.date_range(startDate,endDate)
date_list=[x.strftime('%Y-%m-%d') for x in datelist]
date_list
# Out:
# ['2018-01-01',
#  '2018-01-02',
#  '2018-01-03',
#  '2018-01-04',
#  '2018-01-05',
#  '2018-01-06',
#  '2018-01-07',
#  '2018-01-08',
#  '2018-01-09',
#  '2018-01-10',
#  '2018-01-11',
#  '2018-01-12',
#  '2018-01-13',
#  '2018-01-14',
#  '2018-01-15',
#  '2018-01-16',
#  '2018-01-17',
#  '2018-01-18',
#  '2018-01-19',
#  '2018-01-20',
#  '2018-01-21',
#  '2018-01-22',
#  '2018-01-23',
#  '2018-01-24',
#  '2018-01-25',
#  '2018-01-26',
#  '2018-01-27',
#  '2018-01-28',
#  '2018-01-29',
#  '2018-01-30',
#  '2018-01-31',
#  '2018-02-01',
#  '2018-02-02',
#  '2018-02-03',
#  '2018-02-04',
#  '2018-02-05',
#  '2018-02-06',
#  '2018-02-07',
#  '2018-02-08',
#  '2018-02-09',
#  '2018-02-10',
#  '2018-02-11',
#  '2018-02-12',
#  '2018-02-13',
#  '2018-02-14',
#  '2018-02-15',
#  '2018-02-16',
#  '2018-02-17',
#  '2018-02-18',
#  '2018-02-19',
#  '2018-02-20',
#  '2018-02-21',
#  '2018-02-22',
#  '2018-02-23',
#  '2018-02-24',
#  '2018-02-25',
#  '2018-02-26',
#  '2018-02-27',
# ...
